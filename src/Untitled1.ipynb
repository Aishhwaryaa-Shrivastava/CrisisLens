# %%
import pandas as pd

# Load forecast file
forecasts = pd.read_csv('outputs/reports/simple_forecasts_2026.csv')

# Show column names
print("Available columns:")
print(forecasts.columns.tolist())

# Show first row
print("\nFirst row:")
print(forecasts.head(1))
# Out:
# Available columns:
# ['state', 'current_risk_dec2025', 'ma_forecast_feb2026', 'ma_forecast_mar2026', 'ma_forecast_apr2026', 'lt_forecast_feb2026', 'lt_forecast_mar2026', 'lt_forecast_apr2026', 'best_forecast_feb', 'best_forecast_mar', 'best_forecast_apr']
#
# First row:
#                          state  current_risk_dec2025  ma_forecast_feb2026  \
# 0  Andaman and Nicobar Islands             68.704872            55.760112
#
#    ma_forecast_mar2026  ma_forecast_apr2026  lt_forecast_feb2026  \
# 0            55.760112            55.760112            48.334926
#
#    lt_forecast_mar2026  lt_forecast_apr2026  best_forecast_feb  \
# 0            47.886875            47.438824          48.334926
#
#    best_forecast_mar  best_forecast_apr
# 0          47.886875          47.438824
